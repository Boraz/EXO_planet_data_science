# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline

# %%
HD154345 = pd.read_table('data/HD154345_KECK.vels', sep='\s+', 
                  names = ["velocity", "uncertainty", "S_value", "H_alpha", "median_photons_per_pixel", "exposure_time"])

# %%
print ("Checking that the data is correctly in the table with proper headers")
HD154345.head(3)
# Out:
# Checking that the data is correctly in the table with proper headers
#               velocity  uncertainty  S_value  H_alpha  \
# 2.450547e+06    -24.35         1.45   0.1776     -1.0
# 2.450604e+06    -18.98         1.42   0.1883     -1.0
# 2.450956e+06    -17.30         1.52   0.1784     -1.0
#
#               median_photons_per_pixel  exposure_time
# 2.450547e+06                    145173            250
# 2.450604e+06                    201487            200
# 2.450956e+06                    164367            191

# %%
HD154_F = pd.DataFrame(data=HD154345)

# %%
HD154 = HD154_F[['velocity', 'uncertainty','S_value', 'H_alpha']]

# %%
HD154.plot()

# %%
HD150706_F = pd.read_table('data/HD150706_KECK.vels', sep='\s+', 
                  names = ["velocity", "uncertainty", "S_value", "H_alpha", "median_photons_per_pixel", "exposure_time"])
HD150706 = HD150706_F[['velocity', 'uncertainty','S_value', 'H_alpha']]

# %%
HD150706.plot()

# %%
HD75732_F = pd.read_table('data/HD75732_KECK.vels', sep='\s+', 
                  names = ["velocity", "uncertainty", "S_value", "H_alpha", "median_photons_per_pixel", "exposure_time"])
HD75732 = HD75732_F[['velocity', 'uncertainty','S_value', 'H_alpha']]

# %%
HD75732.plot()

# %%
HD95735_F = pd.read_table('data/HD95735_KECK.vels', sep='\s+', 
                  names = ["velocity", "uncertainty", "S_value", "H_alpha", "median_photons_per_pixel", "exposure_time"])
HD95735 = HD95735_F[['velocity', 'uncertainty','S_value', 'H_alpha']]
HD95735.plot()

# %%
HD207832_F = pd.read_table('data/HD207832_KECK.vels', sep='\s+', 
                  names = ["velocity", "uncertainty", "S_value", "H_alpha", "median_photons_per_pixel", "exposure_time"])
HD207832 = HD207832_F[['velocity', 'uncertainty','S_value', 'H_alpha']]
HD207832.plot()
